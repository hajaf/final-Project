# %%
import pandas as pd

# %%
file_path = "Resources/2015.csv"
df_2015 = pd.read_csv(file_path)
df_2015.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
df_2015.sort_values(by='Country')
# Out:
#          Country                           Region  Happiness Rank  \
# 152  Afghanistan                    Southern Asia             153
# 94       Albania       Central and Eastern Europe              95
# 67       Algeria  Middle East and Northern Africa              68
# 136       Angola               Sub-Saharan Africa             137
# 29     Argentina      Latin America and Caribbean              30
# ..           ...                              ...             ...
# 22     Venezuela      Latin America and Caribbean              23
# 74       Vietnam                Southeastern Asia              75
# 135        Yemen  Middle East and Northern Africa             136
# 84        Zambia               Sub-Saharan Africa              85
# 114     Zimbabwe               Sub-Saharan Africa             115
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 152            3.575         0.03084                   0.31982  0.30285
# ...

# %%
rows_drop = ['Belize', 'Nambilia', 'Puerto Rico', 'Somalia', 'South Sudan', 'Central African Republic', 'Djibouti', 'Lesotho','Mozambique','Oman','Swaziland']

for row in rows_drop:
    df_2015.drop(df_2015[df_2015['Country'] == row].index, inplace = True)

# %%
df_2015.loc[df_2015['Country']=='Central African Republic']
# Out:
# Empty DataFrame
# Columns: [Country, Region, Happiness Rank, Happiness Score, Standard Error, Economy (GDP per Capita), Family, Health (Life Expectancy), Freedom, Trust (Government Corruption), Generosity, Dystopia Residual]
# Index: []

# %%
df_2015.shape
# Out:
# (152, 12)

# %%
file_path = "Resources/2016.csv"
df_2016 = pd.read_csv(file_path)
df_2016.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0      Denmark  Western Europe               1            7.526
# 1  Switzerland  Western Europe               2            7.509
# 2      Iceland  Western Europe               3            7.501
# 3       Norway  Western Europe               4            7.498
# 4      Finland  Western Europe               5            7.413
#
#    Lower Confidence Interval  Upper Confidence Interval  \
# 0                      7.460                      7.592
# 1                      7.428                      7.590
# 2                      7.333                      7.669
# 3                      7.421                      7.575
# 4                      7.351                      7.475
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.44178  1.16374                   0.79504  0.57941
# 1                   1.52733  1.14524                   0.86303  0.58557
# ...
